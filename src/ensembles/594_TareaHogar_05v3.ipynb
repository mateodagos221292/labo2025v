# %% [markdown]
# <a href="https://colab.research.google.com/github/mateodagos221292/labo2025v/blob/main/src/ensembles/594_TareaHogar_05v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 04:44:54 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454474    77.7 1454474  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5944
PARAM$semilla_primigenia <- 131311

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= 10L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.5, # lambda_l1 >= 0.0
  lambda_l2= 0.5, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 0.6, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 1024,
  min_data_in_leaf= 100
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83217
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 05:01:41 PM 2025 AUC 0.924656909486269
#
# Mon Nov 03 05:03:12 PM 2025 AUC 0.925807370507882
#
# Mon Nov 03 05:07:01 PM 2025 AUC 0.928041575457435
#
# Mon Nov 03 05:10:36 PM 2025 AUC 0.925533136858688
#
# Mon Nov 03 05:11:41 PM 2025 AUC 0.924202734104528
#
# Mon Nov 03 05:16:28 PM 2025 AUC 0.924832154906214
#
# Mon Nov 03 05:18:50 PM 2025 AUC 0.925889256704582
#
# Mon Nov 03 05:20:16 PM 2025 AUC 0.92416735546993
#
# Mon Nov 03 05:24:44 PM 2025 AUC 0.924248531461317
#
# Mon Nov 03 05:27:14 PM 2025 AUC 0.928036863973383
#
# Mon Nov 03 05:27:18 PM 2025 AUC 0.92079541902134
#
# Mon Nov 03 05:29:36 PM 2025 AUC 0.925891222928564
#
# Mon Nov 03 05:33:36 PM 2025 AUC 0.926802328833109
#
# Mon Nov 03 05:38:22 PM 2025 AUC 0.926631301378609
#
# Mon Nov 03 05:42:06 PM 2025 AUC 0.922613961713351
#
# Mon Nov 03 05:43:30 PM 2025 AUC 0.918461923012665
#
# Mon Nov 03 05:43:45 PM 2025 AUC 0.917011119922258
#
# Mon Nov 03 05:48:05 PM 2025 AUC 0.921852846979749
#
# Mon Nov 03 05:49:01 PM 2025 AUC 0.927165595125911
#
# Mon Nov 03 05:52:13 PM 2025 AUC 0.925372903948637
#
# [mbo] 0: num_iterations=437; learning_rate=0.128; feature_fraction=0.457; num_leaves=1311; min_data_in_leaf=2634 : y = 0.925 : 96.5 secs : initdesign
#
# [mbo] 0: num_iterations=773; learning_rate=0.115; feature_fraction=0.833; num_leaves=1923; min_data_in_leaf=4513 : y = 0.926 : 90.6 secs : initdesign
#
# [mbo] 0: num_iterations=1888; learning_rate=0.0796; feature_fraction=0.685; num_leaves=425; min_data_in_leaf=3973 : y = 0.928 : 229.5 secs : initdesign
#
# [mbo] 0: num_iterations=1229; learning_rate=0.254; feature_fraction=0.339; num_leaves=978; min_data_in_leaf=5111 : y = 0.926 : 215.1 secs : initdesign
#
# [mbo] 0: num_iterations=312; learning_rate=0.0117; feature_fraction=0.571; num_leaves=564; min_data_in_leaf=1828 : y = 0.924 : 64.7 secs : initdesign
#
# [mbo] 0: num_iterations=1655; learning_rate=0.202; feature_fraction=0.6; num_leaves=845; min_data_in_leaf=2818 : y = 0.925 : 287.4 secs : initdesign
#
# [mbo] 0: num_iterations=1098; learning_rate=0.221; feature_fraction=0.992; num_leaves=775; min_data_in_leaf=3204 : y = 0.926 : 141.6 secs : initdesign
#
# [mbo] 0: num_iterations=524; learning_rate=0.182; feature_fraction=0.29; num_leaves=1186; min_data_in_leaf=6975 : y = 0.924 : 86.0 secs : initdesign
#
# [mbo] 0: num_iterations=1335; learning_rate=0.197; feature_fraction=0.376; num_leaves=1776; min_data_in_leaf=2372 : y = 0.924 : 267.7 secs : initdesign
#
# [mbo] 0: num_iterations=891; learning_rate=0.0836; feature_fraction=0.881; num_leaves=1503; min_data_in_leaf=634 : y = 0.928 : 150.7 secs : initdesign
#
# [mbo] 0: num_iterations=30; learning_rate=0.268; feature_fraction=0.689; num_leaves=167; min_data_in_leaf=6258 : y = 0.921 : 3.7 secs : initdesign
#
# [mbo] 0: num_iterations=668; learning_rate=0.0663; feature_fraction=0.505; num_leaves=1683; min_data_in_leaf=5997 : y = 0.926 : 138.1 secs : initdesign
#
# [mbo] 0: num_iterations=1462; learning_rate=0.0514; feature_fraction=0.278; num_leaves=691; min_data_in_leaf=4367 : y = 0.927 : 240.0 secs : initdesign
#
# [mbo] 0: num_iterations=1270; learning_rate=0.168; feature_fraction=0.468; num_leaves=299; min_data_in_leaf=982 : y = 0.927 : 286.4 secs : initdesign
#
# [mbo] 0: num_iterations=1554; learning_rate=0.231; feature_fraction=0.219; num_leaves=1948; min_data_in_leaf=7981 : y = 0.923 : 223.4 secs : initdesign
#
# [mbo] 0: num_iterations=930; learning_rate=0.289; feature_fraction=0.762; num_leaves=1379; min_data_in_leaf=26 : y = 0.918 : 83.7 secs : initdesign
#
# [mbo] 0: num_iterations=149; learning_rate=0.0284; feature_fraction=0.784; num_leaves=356; min_data_in_leaf=7576 : y = 0.917 : 15.5 secs : initdesign
#
# [mbo] 0: num_iterations=2046; learning_rate=0.282; feature_fraction=0.144; num_leaves=9; min_data_in_leaf=5457 : y = 0.922 : 259.7 secs : initdesign
#
# [mbo] 0: num_iterations=365; learning_rate=0.0972; feature_fraction=0.163; num_leaves=1626; min_data_in_leaf=1387 : y = 0.927 : 56.5 secs : initdesign
#
# [mbo] 0: num_iterations=1830; learning_rate=0.146; feature_fraction=0.946; num_leaves=1117; min_data_in_leaf=6743 : y = 0.925 : 191.5 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:58:45 PM 2025 AUC 0.926939079495587
#
# [mbo] 1: num_iterations=1757; learning_rate=0.078; feature_fraction=0.464; num_leaves=839; min_data_in_leaf=1495 : y = 0.927 : 391.6 secs : infill_ei
#
# Mon Nov 03 06:02:38 PM 2025 AUC 0.927418546172315
#
# [mbo] 2: num_iterations=1962; learning_rate=0.0917; feature_fraction=0.973; num_leaves=908; min_data_in_leaf=4335 : y = 0.927 : 232.7 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:04:41 PM 2025 AUC 0.924953741411172
#
# [mbo] 3: num_iterations=766; learning_rate=0.0542; feature_fraction=0.101; num_leaves=1868; min_data_in_leaf=58 : y = 0.925 : 122.5 secs : infill_ei
#
# Mon Nov 03 06:07:06 PM 2025 AUC 0.928218067609842
#
# [mbo] 4: num_iterations=904; learning_rate=0.101; feature_fraction=0.794; num_leaves=334; min_data_in_leaf=879 : y = 0.928 : 143.9 secs : infill_ei
#
# Mon Nov 03 06:09:10 PM 2025 AUC 0.926269284317663
#
# [mbo] 5: num_iterations=980; learning_rate=0.087; feature_fraction=0.77; num_leaves=294; min_data_in_leaf=3368 : y = 0.926 : 123.4 secs : infill_ei
#
# Mon Nov 03 06:14:26 PM 2025 AUC 0.925293636728333
#
# [mbo] 6: num_iterations=2041; learning_rate=0.081; feature_fraction=0.241; num_leaves=1487; min_data_in_leaf=4879 : y = 0.925 : 316.0 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:18:24 PM 2025 AUC 0.928730314183651
#
# [mbo] 7: num_iterations=1634; learning_rate=0.0918; feature_fraction=0.999; num_leaves=461; min_data_in_leaf=476 : y = 0.929 : 237.4 secs : infill_ei
#
# Mon Nov 03 06:22:04 PM 2025 AUC 0.928172580958644
#
# [mbo] 8: num_iterations=1360; learning_rate=0.0992; feature_fraction=0.999; num_leaves=745; min_data_in_leaf=835 : y = 0.928 : 219.5 secs : infill_ei
#
# Mon Nov 03 06:26:40 PM 2025 AUC 0.928656544585708
#
# [mbo] 9: num_iterations=1773; learning_rate=0.0897; feature_fraction=0.999; num_leaves=84; min_data_in_leaf=1008 : y = 0.929 : 275.5 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:30:32 PM 2025 AUC 0.929280536043717
#
# [mbo] 10: num_iterations=1362; learning_rate=0.0797; feature_fraction=0.975; num_leaves=274; min_data_in_leaf=548 : y = 0.929 : 230.8 secs : infill_ei
#
# Mon Nov 03 06:32:42 PM 2025 AUC 0.930927024664835
#
# [mbo] 11: num_iterations=1532; learning_rate=0.0648; feature_fraction=0.998; num_leaves=8; min_data_in_leaf=502 : y = 0.931 : 129.3 secs : infill_ei
#
# Mon Nov 03 06:37:53 PM 2025 AUC 0.92691380187723
#
# [mbo] 12: num_iterations=2032; learning_rate=0.0633; feature_fraction=0.965; num_leaves=234; min_data_in_leaf=1240 : y = 0.927 : 311.1 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:39:38 PM 2025 AUC 0.9294687773272
#
# [mbo] 13: num_iterations=1308; learning_rate=0.0634; feature_fraction=0.687; num_leaves=8; min_data_in_leaf=4 : y = 0.929 : 104.0 secs : infill_ei
#
# Mon Nov 03 06:42:16 PM 2025 AUC 0.928340195300331
#
# [mbo] 14: num_iterations=1726; learning_rate=0.0144; feature_fraction=0.974; num_leaves=9; min_data_in_leaf=358 : y = 0.928 : 157.4 secs : infill_ei
#
# Mon Nov 03 06:44:30 PM 2025 AUC 0.927915230908399
#
# [mbo] 15: num_iterations=1535; learning_rate=0.0555; feature_fraction=0.883; num_leaves=8; min_data_in_leaf=994 : y = 0.928 : 133.9 secs : infill_ei
#
# Mon Nov 03 06:46:44 PM 2025 AUC 0.928598652313089
#
# [mbo] 16: num_iterations=1602; learning_rate=0.0795; feature_fraction=0.999; num_leaves=8; min_data_in_leaf=242 : y = 0.929 : 132.6 secs : infill_ei
#
# Mon Nov 03 06:49:45 PM 2025 AUC 0.928446232099429
#
# [mbo] 17: num_iterations=1175; learning_rate=0.0673; feature_fraction=0.999; num_leaves=67; min_data_in_leaf=1137 : y = 0.928 : 180.6 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:50:44 PM 2025 AUC 0.92846949978059
#
# [mbo] 18: num_iterations=344; learning_rate=0.0629; feature_fraction=0.999; num_leaves=209; min_data_in_leaf=377 : y = 0.928 : 59.3 secs : infill_ei
#
# Mon Nov 03 06:55:01 PM 2025 AUC 0.928327282737828
#
# [mbo] 19: num_iterations=1482; learning_rate=0.0666; feature_fraction=0.828; num_leaves=513; min_data_in_leaf=442 : y = 0.928 : 256.2 secs : infill_ei
#
# Mon Nov 03 06:58:32 PM 2025 AUC 0.929987642662987
#
# [mbo] 20: num_iterations=1244; learning_rate=0.064; feature_fraction=0.368; num_leaves=9; min_data_in_leaf=510 : y = 0.93 : 210.2 secs : infill_ei
#
# Mon Nov 03 07:03:05 PM 2025 AUC 0.926953462630608
#
# [mbo] 21: num_iterations=1629; learning_rate=0.146; feature_fraction=0.287; num_leaves=361; min_data_in_leaf=4140 : y = 0.927 : 272.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:05:07 PM 2025 AUC 0.930015441848592
#
# [mbo] 22: num_iterations=1306; learning_rate=0.0595; feature_fraction=0.883; num_leaves=11; min_data_in_leaf=482 : y = 0.93 : 121.3 secs : infill_ei
#
# Mon Nov 03 07:11:18 PM 2025 AUC 0.928274336969475
#
# [mbo] 23: num_iterations=1841; learning_rate=0.123; feature_fraction=0.447; num_leaves=21; min_data_in_leaf=603 : y = 0.928 : 370.5 secs : infill_ei
#
# Mon Nov 03 07:11:58 PM 2025 AUC 0.930002113199783
#
# [mbo] 24: num_iterations=216; learning_rate=0.0546; feature_fraction=0.33; num_leaves=16; min_data_in_leaf=644 : y = 0.93 : 39.8 secs : infill_ei
#
# Mon Nov 03 07:13:07 PM 2025 AUC 0.929889464696348
#
# [mbo] 25: num_iterations=521; learning_rate=0.0708; feature_fraction=0.176; num_leaves=8; min_data_in_leaf=627 : y = 0.93 : 68.6 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:13:11 PM 2025 AUC 0.912349148916981
#
# [mbo] 26: num_iterations=14; learning_rate=0.0947; feature_fraction=0.244; num_leaves=11; min_data_in_leaf=1158 : y = 0.912 : 2.9 secs : infill_ei
#
# Mon Nov 03 07:17:17 PM 2025 AUC 0.930594963576951
#
# [mbo] 27: num_iterations=1237; learning_rate=0.0103; feature_fraction=0.594; num_leaves=196; min_data_in_leaf=443 : y = 0.931 : 246.3 secs : infill_ei
#
# Mon Nov 03 07:17:58 PM 2025 AUC 0.927067924494657
#
# [mbo] 28: num_iterations=259; learning_rate=0.0361; feature_fraction=0.116; num_leaves=83; min_data_in_leaf=87 : y = 0.927 : 39.8 secs : infill_ei
#
# Mon Nov 03 07:19:07 PM 2025 AUC 0.929984517583353
#
# [mbo] 29: num_iterations=557; learning_rate=0.0605; feature_fraction=0.143; num_leaves=9; min_data_in_leaf=458 : y = 0.93 : 68.9 secs : infill_ei
#
# Mon Nov 03 07:21:53 PM 2025 AUC 0.928855044404369
#
# [mbo] 30: num_iterations=837; learning_rate=0.012; feature_fraction=0.521; num_leaves=8; min_data_in_leaf=532 : y = 0.929 : 165.0 secs : infill_ei
#
# Mon Nov 03 07:25:14 PM 2025 AUC 0.925263057686
#
# [mbo] 31: num_iterations=1473; learning_rate=0.0636; feature_fraction=0.178; num_leaves=11; min_data_in_leaf=4954 : y = 0.925 : 200.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:28:55 PM 2025 AUC 0.930720318752094
#
# [mbo] 32: num_iterations=1061; learning_rate=0.039; feature_fraction=0.342; num_leaves=286; min_data_in_leaf=396 : y = 0.931 : 220.3 secs : infill_ei
#
# Mon Nov 03 07:30:18 PM 2025 AUC 0.927130525788273
#
# [mbo] 33: num_iterations=385; learning_rate=0.0581; feature_fraction=0.357; num_leaves=484; min_data_in_leaf=327 : y = 0.927 : 82.2 secs : infill_ei
#
# Mon Nov 03 07:36:16 PM 2025 AUC 0.930858217113525
#
# [mbo] 34: num_iterations=1982; learning_rate=0.0113; feature_fraction=0.241; num_leaves=563; min_data_in_leaf=438 : y = 0.931 : 357.4 secs : infill_ei
#
# Saved the current state after iteration 35 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:40:18 PM 2025 AUC 0.928500249744222
#
# [mbo] 35: num_iterations=1407; learning_rate=0.0153; feature_fraction=0.198; num_leaves=407; min_data_in_leaf=380 : y = 0.929 : 240.9 secs : infill_ei
#
# Mon Nov 03 07:46:56 PM 2025 AUC 0.929576804827104
#
# [mbo] 36: num_iterations=2043; learning_rate=0.0317; feature_fraction=0.296; num_leaves=312; min_data_in_leaf=502 : y = 0.93 : 398.0 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:49:49 PM 2025 AUC 0.930053949633704
#
# [mbo] 37: num_iterations=869; learning_rate=0.0524; feature_fraction=0.595; num_leaves=170; min_data_in_leaf=655 : y = 0.93 : 172.5 secs : infill_ei
#
# Mon Nov 03 07:54:47 PM 2025 AUC 0.927934015427385
#
# [mbo] 38: num_iterations=1141; learning_rate=0.011; feature_fraction=0.376; num_leaves=250; min_data_in_leaf=1 : y = 0.928 : 297.2 secs : infill_ei
#
# Mon Nov 03 07:57:32 PM 2025 AUC 0.925488578598939
#
# [mbo] 39: num_iterations=786; learning_rate=0.151; feature_fraction=0.351; num_leaves=190; min_data_in_leaf=457 : y = 0.925 : 164.3 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:00:43 PM 2025 AUC 0.931232928530012
#
# [mbo] 40: num_iterations=1025; learning_rate=0.044; feature_fraction=0.451; num_leaves=8; min_data_in_leaf=580 : y = 0.931 : 190.3 secs : infill_ei
#
# Mon Nov 03 08:03:21 PM 2025 AUC 0.930532857497569
#
# [mbo] 41: num_iterations=965; learning_rate=0.0391; feature_fraction=0.31; num_leaves=16; min_data_in_leaf=2 : y = 0.931 : 157.3 secs : infill_ei
#
# Mon Nov 03 08:10:43 PM 2025 AUC 0.930155058268229
#
# [mbo] 42: num_iterations=2044; learning_rate=0.0105; feature_fraction=0.575; num_leaves=699; min_data_in_leaf=603 : y = 0.93 : 442.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:14:34 PM 2025 AUC 0.931123981811108
#
# [mbo] 43: num_iterations=1248; learning_rate=0.0354; feature_fraction=0.363; num_leaves=21; min_data_in_leaf=436 : y = 0.931 : 229.7 secs : infill_ei
#
# Mon Nov 03 08:18:15 PM 2025 AUC 0.929223518637613
#
# [mbo] 44: num_iterations=1834; learning_rate=0.0391; feature_fraction=0.611; num_leaves=10; min_data_in_leaf=270 : y = 0.929 : 221.0 secs : infill_ei
#
# Mon Nov 03 08:22:20 PM 2025 AUC 0.929198200695789
#
# [mbo] 45: num_iterations=1609; learning_rate=0.0477; feature_fraction=0.956; num_leaves=39; min_data_in_leaf=621 : y = 0.929 : 243.9 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:25:28 PM 2025 AUC 0.930479585544777
#
# [mbo] 46: num_iterations=983; learning_rate=0.0308; feature_fraction=0.601; num_leaves=447; min_data_in_leaf=675 : y = 0.93 : 187.4 secs : infill_ei
#
# Mon Nov 03 08:27:40 PM 2025 AUC 0.927676251430555
#
# [mbo] 47: num_iterations=1007; learning_rate=0.0362; feature_fraction=0.103; num_leaves=31; min_data_in_leaf=692 : y = 0.928 : 132.0 secs : infill_ei
#
# Mon Nov 03 08:33:01 PM 2025 AUC 0.928202941160418
#
# [mbo] 48: num_iterations=1228; learning_rate=0.0343; feature_fraction=0.573; num_leaves=150; min_data_in_leaf=19 : y = 0.928 : 319.7 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:37:07 PM 2025 AUC 0.93125036037585
#
# [mbo] 49: num_iterations=1096; learning_rate=0.0388; feature_fraction=0.418; num_leaves=955; min_data_in_leaf=611 : y = 0.931 : 245.6 secs : infill_ei
#
# Mon Nov 03 08:42:20 PM 2025 AUC 0.930802018088395
#
# [mbo] 50: num_iterations=1391; learning_rate=0.0279; feature_fraction=0.429; num_leaves=981; min_data_in_leaf=761 : y = 0.931 : 312.7 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1096    0.03880775        0.4184623        955              611
# [1] 0.9312504

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 131311
#
# $max_depth
# [1] 10
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0.5
#
# $lambda_l2
# [1] 0.5
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.6
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1096
#
# $learning_rate
# [1] 0.03880775
#
# $feature_fraction
# [1] 0.4184623
#
# $num_leaves
# [1] 955
#
# $min_data_in_leaf
# [1] 611

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 09:32:04 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
